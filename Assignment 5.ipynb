# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)

def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))


vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
del words  # Hint to reduce memory.
print('sample data index:', [di for di in data[:8]])
print('sample data:', [reverse_dictionary[di] for di in data[:8]])

data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# sample data index: [5239, 3081, 12, 6, 195, 2, 3134, 46]
# sample data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']

# %%
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'originated', 'of', 'as', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.041775
# Nearest to when: austral, acquaintance, mckernan, jamil, milne, yorktown, topics, northwest,
# Nearest to so: classed, superconductors, bpp, chance, coaches, batsman, ishtar, clusters,
# Nearest to years: squalor, resource, ecologically, turning, polyn, alvar, peg, automaker,
# Nearest to as: refinery, cpus, buttons, keep, handhelds, venous, teamsters, gallagher,
# Nearest to zero: infrequent, further, newtons, orbit, cristina, godlike, granary, heft,
# Nearest to not: sleep, identifiable, administrator, mawson, pelias, amathus, specifies, encourages,
# Nearest to history: delaying, flair, fairchild, transplantation, stable, fiancee, malayan, barnet,
# Nearest to three: bassoonist, insists, logograms, pushes, sidearm, cowpox, icty, nss,
# Nearest to to: osman, canada, futurists, pozna, fence, reduce, foreskin, nazarene,
# Nearest to was: marmara, vanes, ascendancy, dramatized, battlefield, dundas, pron, water,
# Nearest to of: kabuki, blink, makeshift, cornerback, chef, dispatch, invaders, busts,
# Nearest to during: camden, glimpse, primacy, bacterial, explored, longue, gilgal, dots,
# Nearest to new: ives, gpmg, fulgencio, wissenschaften, waterfront, healer, hoddle, coon,
# Nearest to six: aloes, spectacularly, logical, mik, maglev, collins, ansi, snowfall,
# Nearest to people: aristides, nakajima, racism, basil, initiating, boulevard, writable, exercised,
# Nearest to between: communities, hitachi, arsenide, pfa, brains, targeting, uw, megali,
# Average loss at step 2000: 4.365262
# Average loss at step 4000: 3.868525
# Average loss at step 6000: 3.785580
# Average loss at step 8000: 3.681314
# Average loss at step 10000: 3.618356
# Nearest to when: mckernan, ridinghood, became, antipodes, drexel, jamil, epoxy, jp,
# Nearest to so: classed, superconductors, preprocessing, elitism, clusters, chance, sh, cryptozoologists,
# Nearest to years: squalor, ecologically, alvar, rovers, darpa, undiscovered, extraterrestrials, dempsey,
# Nearest to as: zodiacal, gradients, incited, became, precedent, since, osprey, is,
# Nearest to zero: eight, nine, seven, six, five, three, four, two,
# Nearest to not: it, they, identifiable, still, there, mawson, also, cv,
# Nearest to history: names, transplantation, delaying, doctorates, hash, rassemblement, fiancee, flair,
# Nearest to three: four, six, seven, five, eight, two, nine, zero,
# Nearest to to: would, output, nicaraguan, dockyard, foreskin, can, same, not,
# Nearest to was: is, has, were, had, be, been, by, dubnium,
# Nearest to of: in, from, for, kitten, arcy, including, and, textiles,
# Nearest to during: camden, farthest, porvoo, pointer, at, bacterial, microprocessor, glimpse,
# Nearest to new: gpmg, waterfront, sociolinguistics, eastern, ives, wissenschaften, awaited, wheaton,
# Nearest to six: eight, seven, five, four, three, nine, zero, two,
# Nearest to people: others, nihilism, initiating, fruiting, wasting, boulevard, historical, nakajima,
# Nearest to between: courtyards, dobbs, communities, coastal, with, megali, targeting, yearning,
# Average loss at step 12000: 3.604418
# Average loss at step 14000: 3.576117
# Average loss at step 16000: 3.409834
# Average loss at step 18000: 3.456009
# Average loss at step 20000: 3.541118
# Nearest to when: before, where, if, at, draper, became, jp, epoxy,
# Nearest to so: classed, preprocessing, chance, sh, cryptozoologists, clusters, disulfide, elitism,
# Nearest to years: squalor, rovers, people, days, dempsey, alvar, polyn, honeywell,
# Nearest to as: zodiacal, shaping, fearful, cfr, became, precedent, when, wooden,
# Nearest to zero: six, seven, five, eight, nine, four, three, two,
# Nearest to not: still, it, they, rifts, also, to, embarks, raster,
# Nearest to history: transplantation, hash, rassemblement, delaying, irreversibly, names, cabot, sunset,
# Nearest to three: seven, four, five, six, two, eight, zero, nine,
# Nearest to to: will, would, could, can, may, must, dockyard, not,
# Nearest to was: is, were, has, had, became, be, been, are,
# Nearest to of: geos, diss, arcy, including, for, ev, peel, spectral,
# Nearest to during: farthest, camden, until, under, porvoo, fray, microprocessor, uncovering,
# Nearest to new: gpmg, waterfront, sociolinguistics, wheaton, hoddle, ives, dubrovnik, wissenschaften,
# Nearest to six: seven, eight, nine, four, five, three, zero, two,
# Nearest to people: others, grothendieck, initiating, men, years, olivier, historical, nihilism,
# Nearest to between: with, megali, dobbs, baez, coastal, at, communities, courtyards,
# Average loss at step 22000: 3.494207
# Average loss at step 24000: 3.489289
# Average loss at step 26000: 3.481362
# Average loss at step 28000: 3.482067
# Average loss at step 30000: 3.501044
# Nearest to when: if, before, where, after, while, however, for, at,
# Nearest to so: classed, chance, disulfide, perilous, westerner, preprocessing, clusters, lobbyist,
# Nearest to years: days, squalor, rovers, year, months, people, cornerstones, polyn,
# Nearest to as: zodiacal, slovak, became, cfr, cary, be, symmetries, potatoes,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to not: still, they, it, rifts, apollos, raster, this, sala,
# Nearest to history: names, consists, transplantation, hash, irreversibly, cabot, rassemblement, judgments,
# Nearest to three: four, seven, five, eight, six, two, nine, zero,
# Nearest to to: would, must, will, can, could, nicaraguan, gion, cannot,
# Nearest to was: is, had, has, were, became, been, sponsorship, when,
# Nearest to of: geos, grandmother, in, troubling, arcy, for, and, including,
# Nearest to during: in, until, after, farthest, under, before, when, camden,
# Nearest to new: gpmg, naval, latest, gion, awaited, wissenschaften, ives, tailed,
# Nearest to six: eight, four, seven, five, nine, three, zero, two,
# Nearest to people: others, men, children, grothendieck, years, fruiting, nakajima, women,
# Nearest to between: with, baez, against, dobbs, nguema, among, coastal, targeting,
# Average loss at step 32000: 3.502131
# Average loss at step 34000: 3.493660
# Average loss at step 36000: 3.457282
# Average loss at step 38000: 3.302946
# Average loss at step 40000: 3.431828
# Nearest to when: if, before, while, where, after, but, is, was,
# Nearest to so: classed, disulfide, chance, perilous, clusters, asturias, flaws, splashdown,
# Nearest to years: days, months, year, squalor, cornerstones, rovers, decades, times,
# Nearest to as: fearful, when, potatoes, stewards, zodiacal, materialist, mores, keep,
# Nearest to zero: seven, five, nine, eight, six, three, four, two,
# Nearest to not: still, it, you, they, rifts, only, enos, never,
# Nearest to history: demographics, names, cabot, website, rave, cryoprotectant, hash, consists,
# Nearest to three: four, seven, five, two, six, eight, nine, zero,
# Nearest to to: would, will, nicaraguan, from, may, guarantee, can, gaels,
# Nearest to was: is, were, became, had, has, been, when, be,
# Nearest to of: in, arcy, geos, from, spectral, ping, transclusion, troubling,
# Nearest to during: farthest, before, until, in, after, against, at, when,
# Nearest to new: modern, gpmg, awaited, waterfront, dubrovnik, invariant, sociolinguistics, naval,
# Nearest to six: seven, four, five, eight, three, nine, two, zero,
# Nearest to people: others, hotspot, men, children, wasting, years, aldosterone, many,
# Nearest to between: with, over, against, among, around, dobbs, through, into,
# Average loss at step 42000: 3.435337
# Average loss at step 44000: 3.455364
# Average loss at step 46000: 3.447720
# Average loss at step 48000: 3.354142
# Average loss at step 50000: 3.385107
# Nearest to when: if, before, while, where, after, although, but, during,
# Nearest to so: classed, clusters, perilous, ghola, if, says, pierson, disulfide,
# Nearest to years: days, months, year, times, people, decades, weeks, cornerstones,
# Nearest to as: became, zodiacal, including, cfr, precedent, stewards, editing, materialist,
# Nearest to zero: seven, eight, five, six, four, nine, three, two,
# Nearest to not: still, rifts, it, enos, never, usually, largely, wolsey,
# Nearest to history: demographics, transplantation, decade, website, modulation, list, hash, zvi,
# Nearest to three: seven, four, six, eight, two, five, nine, zero,
# Nearest to to: may, must, might, wiktionary, will, could, would, guarantee,
# Nearest to was: is, has, became, were, had, be, been, being,
# Nearest to of: in, and, arcy, advisory, grandmother, reconsider, including, lacks,
# Nearest to during: under, in, before, after, when, at, until, uncovering,
# Nearest to new: waterfront, latest, mortgages, deaf, dubrovnik, finned, awaited, naval,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Nearest to people: others, children, men, years, hotspot, aldosterone, vitrification, optimistic,
# Nearest to between: with, against, baez, among, through, dobbs, around, clich,
# Average loss at step 52000: 3.442351
# Average loss at step 54000: 3.425601
# Average loss at step 56000: 3.436403
# Average loss at step 58000: 3.398333
# Average loss at step 60000: 3.396349
# Nearest to when: if, before, although, while, after, because, where, though,
# Nearest to so: too, if, classed, bri, chojn, clusters, perilous, nothing,
# Nearest to years: days, months, year, decades, times, weeks, centuries, minutes,
# Nearest to as: zodiacal, epicurus, including, nasl, keep, in, fabulous, when,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to not: still, never, usually, you, they, now, nearly, it,
# Nearest to history: demographics, list, geography, book, modulation, zvi, bestseller, politics,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to to: would, will, may, must, might, centrioles, not, nther,
# Nearest to was: is, had, became, has, were, although, been, becomes,
# Nearest to of: geos, in, including, arcy, msx, grandmother, for, same,
# Nearest to during: after, in, before, under, following, although, until, when,
# Nearest to new: latest, gpmg, keyboard, awaited, kanchenjunga, finned, smoker, referee,
# Nearest to six: eight, four, five, nine, seven, three, zero, two,
# Nearest to people: men, others, kalinga, scientists, countries, someone, women, optimistic,
# Nearest to between: with, among, against, baez, in, through, over, around,
# Average loss at step 62000: 3.243323
# Average loss at step 64000: 3.255349
# Average loss at step 66000: 3.402426
# Average loss at step 68000: 3.392713
# Average loss at step 70000: 3.363817
# Nearest to when: if, before, while, because, where, after, although, though,
# Nearest to so: too, sometimes, if, perilous, ghola, classed, chojn, clusters,
# Nearest to years: days, months, year, decades, times, weeks, centuries, indignation,
# Nearest to as: is, like, using, shaping, while, in, fabulous, wooden,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to not: still, never, now, almost, usually, always, rifts, identifiable,
# Nearest to history: list, demographics, modulation, consists, geography, book, zvi, politics,
# Nearest to three: six, four, five, two, seven, eight, nine, zero,
# Nearest to to: will, would, can, might, must, gaels, could, centrioles,
# Nearest to was: is, has, had, were, became, been, although, becomes,
# Nearest to of: including, in, arcy, transclusion, and, include, geos, actual,
# Nearest to during: after, before, in, until, at, under, throughout, uppercase,
# Nearest to new: latest, keyboard, meyers, waterfront, kanchenjunga, different, grammy, carboniferous,
# Nearest to six: eight, five, nine, four, seven, three, zero, two,
# Nearest to people: men, others, women, countries, members, kalinga, children, embryogenesis,
# Nearest to between: with, among, baez, against, through, around, nucleotide, within,
# Average loss at step 72000: 3.372732
# Average loss at step 74000: 3.352329
# Average loss at step 76000: 3.321310
# Average loss at step 78000: 3.353762
# Average loss at step 80000: 3.378843
# Nearest to when: if, before, after, while, though, although, where, during,
# Nearest to so: if, clusters, too, then, desiring, chojn, classed, bogart,
# Nearest to years: days, months, year, decades, weeks, times, minutes, centuries,
# Nearest to as: epicurus, when, oligopoly, potatoes, witty, splitflag, deceiving, including,
# Nearest to zero: seven, five, eight, four, six, nine, three, two,
# Nearest to not: still, never, usually, it, almost, now, they, generally,
# Nearest to history: list, hash, consists, geography, decade, demographics, modulation, cabot,
# Nearest to three: six, four, five, seven, eight, two, nine, zero,
# Nearest to to: will, bilirubin, must, would, should, gaels, towards, centrioles,
# Nearest to was: is, were, became, had, has, been, although, seems,
# Nearest to of: in, geos, fyodorovna, arcy, including, pointe, colourful, sem,
# Nearest to during: after, in, before, when, throughout, until, although, following,
# Nearest to new: renaissance, latest, waterfront, modern, suitably, marketed, socks, different,
# Nearest to six: five, four, seven, eight, three, nine, two, zero,
# Nearest to people: men, women, countries, members, others, children, someone, scientists,
# Nearest to between: among, against, with, within, around, through, over, tsunamis,
# Average loss at step 82000: 3.405440
# Average loss at step 84000: 3.412730
# Average loss at step 86000: 3.389058
# Average loss at step 88000: 3.356355
# Average loss at step 90000: 3.368379
# Nearest to when: if, before, while, after, where, although, though, because,
# Nearest to so: too, if, thus, clusters, chojn, balanced, colleen, bogart,
# Nearest to years: days, months, decades, year, weeks, minutes, centuries, hours,
# Nearest to as: lodovico, zodiacal, epicurus, quesada, potatoes, including, jasmuheen, broader,
# Nearest to zero: five, seven, eight, six, four, nine, three, two,
# Nearest to not: still, they, it, never, without, we, usually, almost,
# Nearest to history: list, hash, demographics, modulation, fbi, horticulture, archaeological, kilograms,
# Nearest to three: two, five, four, seven, eight, six, nine, zero,
# Nearest to to: will, towards, would, gaels, bilirubin, might, should, comprises,
# Nearest to was: is, were, became, had, be, has, glissando, becomes,
# Nearest to of: for, colourful, in, geos, fyodorovna, pointe, including, admixture,
# Nearest to during: after, in, before, under, throughout, although, until, at,
# Nearest to new: latest, mecha, specific, scorsese, completes, yamato, finned, modern,
# Nearest to six: seven, four, eight, five, nine, three, zero, two,
# Nearest to people: women, men, members, children, someone, kalinga, scientists, christians,
# Nearest to between: among, with, against, within, over, around, baez, through,
# Average loss at step 92000: 3.398829
# Average loss at step 94000: 3.254480
# Average loss at step 96000: 3.354704
# Average loss at step 98000: 3.243760
# Average loss at step 100000: 3.359814
# Nearest to when: if, while, before, where, although, after, because, though,
# Nearest to so: thus, too, bogart, later, clusters, eventually, if, while,
# Nearest to years: days, months, year, decades, weeks, centuries, minutes, hours,
# Nearest to as: shaping, cfr, nasl, potatoes, quesada, when, like, although,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to not: still, never, nor, you, t, they, enos, almost,
# Nearest to history: list, demographics, modulation, hash, geography, rave, archaeological, kilograms,
# Nearest to three: five, four, seven, six, eight, two, nine, zero,
# Nearest to to: will, would, towards, should, can, might, nther, must,
# Nearest to was: is, became, were, had, has, been, does, did,
# Nearest to of: geos, including, fyodorovna, in, merlot, transclusion, original, grandmother,
# Nearest to during: in, after, before, throughout, following, until, when, under,
# Nearest to new: latest, different, specific, smoker, save, disguises, awaited, modern,
# Nearest to six: seven, four, five, eight, nine, three, two, zero,
# Nearest to people: women, men, children, members, countries, scientists, someone, players,
# Nearest to between: among, with, against, baez, within, over, autocephalous, around,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
# Now for CBOW


def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels
