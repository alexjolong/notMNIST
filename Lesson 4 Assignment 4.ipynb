# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)

image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)


def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    pool = tf.nn.max_pool(data, [1,2,2,1], [1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, [1,2,2,1], [1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.400999
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.770602
# Minibatch accuracy: 43.8%
# Validation accuracy: 58.7%
# Minibatch loss at step 100: 1.071033
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.2%
# Minibatch loss at step 150: 1.126480
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 200: 0.790297
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 250: 1.386748
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 300: 0.908683
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 350: 0.893628
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 400: 0.816830
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 450: 0.349745
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 500: 0.455329
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 550: 0.307943
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 600: 0.724597
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 650: 0.624282
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 700: 0.350509
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 750: 0.195802
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 800: 1.219633
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 850: 0.179637
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.7%
# Minibatch loss at step 900: 0.169008
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 950: 0.914812
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.9%
# Minibatch loss at step 1000: 0.704262
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Test accuracy: 89.5%

# %%
"""
Our best performing algorithm (97.0%) from before, which used 4 hidden layers with smartly optimized weights. 
We will replace the fully connected layers with convolutions (same padding, strides of 2).

After training 95001 steps w/ batch size of 16, test score was 95.2%
"""

#batch_size = 128
layer1_size = 1024
layer2_size = 1024
layer3_size = 305
layer4_size = 75
# note, logits_size == num_labels

batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64


layer1_weights_stdev = 0.0517
layer2_weights_stdev = 0.0441
layer3_weights_stdev = 0.0441
layer4_weights_stdev = 0.0809
logits_weights_stdev = 0.1632

regularization_meta = 0.03
keepprob = 0.75

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  """ 
  # Old layer weights.
  layer1_weights = tf.Variable(tf.truncated_normal([image_size * image_size, layer1_size], stddev=layer1_weights_stdev))
  layer2_weights = tf.Variable(tf.truncated_normal([layer1_size, layer2_size], stddev=layer2_weights_stdev))
  layer3_weights = tf.Variable(tf.truncated_normal([layer2_size, layer3_size], stddev=layer3_weights_stdev))
  layer4_weights = tf.Variable(tf.truncated_normal([layer3_size, layer4_size], stddev=layer4_weights_stdev))
  logits_weights = tf.Variable(tf.truncated_normal([layer4_size, num_labels], stddev=logits_weights_stdev))
  
  # Old layer biases.
  layer1_biases = tf.Variable(tf.zeros([layer1_size]))
  layer2_biases = tf.Variable(tf.zeros([layer2_size]))
  layer3_biases = tf.Variable(tf.zeros([layer3_size]))
  layer4_biases = tf.Variable(tf.zeros([layer4_size]))
  logits_biases = tf.Variable(tf.zeros([num_labels]))
  """

  # New layer weights
  layer1_weights = tf.Variable(tf.truncated_normal([5, 5, 1, 16], stddev=layer1_weights_stdev))
  layer2_weights = tf.Variable(tf.truncated_normal([5, 5, 16, 16], stddev=layer2_weights_stdev))
  layer3_weights = tf.Variable(tf.truncated_normal([784, 64], stddev=layer3_weights_stdev))
  layer4_weights = tf.Variable(tf.truncated_normal([64, 10], stddev=layer4_weights_stdev))

  # New layer biases
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
    
  
  def apply_layers(dataset, use_dropout=False):
    conv = tf.nn.conv2d(dataset, layer1_weights, [1, 2, 2, 1], padding='SAME')
    layer = tf.nn.relu(conv + layer1_biases)
    if use_dropout:
        layer = tf.nn.dropout(layer, keepprob)
    
    conv = tf.nn.conv2d(layer, layer2_weights, [1, 2, 2, 1], padding='SAME')
    layer = tf.nn.relu(conv + layer2_biases)
    if use_dropout:
        layer = tf.nn.dropout(layer, keepprob)

    shape = layer.get_shape().as_list()
    reshape = tf.reshape(layer, [shape[0], shape[1] * shape[2] * shape[3]])
    layer = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    if use_dropout:
        layer = tf.nn.dropout(layer, keepprob)
    
    # one fully connected layer at the end
    logits = tf.matmul(layer, layer4_weights) + layer4_biases
    return logits

  # Training computation.
  train_logits = apply_layers(tf_train_dataset, True)
  valid_logits = apply_layers(tf_valid_dataset)
  test_logits = apply_layers(tf_test_dataset)

  train_loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=train_logits))
  #loss_l2 = train_loss + (regularization_meta * (tf.nn.l2_loss(weights2)))
  
  # Optimizer.
  global_step = tf.Variable(0, trainable=False)  # count the number of steps taken.
  learning_rate = tf.train.exponential_decay(0.3, global_step, 3500, 0.86, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(train_loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(train_logits)
  valid_prediction = tf.nn.softmax(valid_logits)
  test_prediction = tf.nn.softmax(test_logits)

# %%
num_steps = 95001


with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
    
    
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, train_loss, train_prediction], feed_dict=feed_dict)
    if (step % 1000 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.583692
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.2%
# Minibatch loss at step 1000: 0.808243
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.7%
# Minibatch loss at step 2000: 0.589585
# Minibatch accuracy: 75.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-5c5a4fb12205> in <module>()
#      24       print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
#      25       print("Validation accuracy: %.1f%%" % accuracy(
# ---> 26         valid_prediction.eval(), valid_labels))
#      27   print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in eval(self, feed_dict, session)
#     604
#     605     """
# --> 606     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     607
#     608
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    3926                        "the tensor's graph is different from the session's "
#    3927                        "graph.")
# -> 3928   return session.run(tensors, feed_dict)
#    3929
#    3930
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
"""
We will use the same model as above, but with 4 convolutional layers and with pooling

Test accuracy w/ two convolutions: 93.5%

Edit: for some reason, with any more than two convolutions, my validation score would drop down to 10% (random chance) 
on every epoch after the first three batches. I think I may be narrowing down my image too quickly (2 rounds of max 
pooling with strides of 2, kernels of 3x3). With such simple (and small) image types, maybe TOO MUCH feature extraction 
ends up just randomizing? I might try a deeper model later, with a softer approach, maybe some 5x5 kernels with same 
padding and strides of 1? 28 -> 26 -> 24 -> etc....

Oorr, try it out with valid padding. The edges of the image probably don't matter much, so we can underemphasize them.

Also, is it a good idea to make convolution layers that have more elements than their inputs? Like 28x28x1 -> 26x26x4 ->
24x24x16 -> etc. My hunch is that this would overemphasize the same features pretty quickly, although with dropout
this might balance.

"""

batch_size = 16

layer1_weights_stdev = 0.0517
layer2_weights_stdev = 0.0441
layer3_weights_stdev = 0.0441
layer4_weights_stdev = 0.0809
logits_weights_stdev = 0.1632

regularization_meta = 0.03
keepprob = 0.75


graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  

  # New layer weights
  layer1_weights = tf.Variable(tf.truncated_normal([3, 3, num_channels, 4], stddev=layer1_weights_stdev))
  layer2_weights = tf.Variable(tf.truncated_normal([3, 3, 4, 16], stddev=layer2_weights_stdev))
  layer3_weights = tf.Variable(tf.truncated_normal([3, 3, 16, 49], stddev=layer3_weights_stdev))
  layer4_weights = tf.Variable(tf.truncated_normal([784, 64], stddev=layer4_weights_stdev))
  layer5_weights = tf.Variable(tf.truncated_normal([64, num_labels], stddev=layer5_weights_stdev))

  # New layer biases
  layer1_biases = tf.Variable(tf.zeros([4]))
  layer2_biases = tf.Variable(tf.zeros([16]))
  layer3_biases = tf.Variable(tf.zeros([49]))
  layer4_biases = tf.Variable(tf.zeros([64]))
  layer5_biases = tf.Variable(tf.zeros([num_labels]))
  
  def apply_layers(dataset, use_dropout=False):
    pool = tf.nn.max_pool(dataset, [1,3,3,1], [1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer1_weights, [1,1,1,1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    if use_dropout:
        hidden = tf.nn.dropout(hidden, keepprob)
    
    pool = tf.nn.max_pool(hidden, [1,3,3,1], [1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1,1,1,1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    if use_dropout:
        hidden = tf.nn.dropout(hidden, keepprob)

    """
    pool = tf.nn.max_pool(hidden, [1,3,3,1], [1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer3_weights, [1,1,1,1], padding='SAME')
    hidden = tf.nn.relu(conv + layer3_biases)
    if use_dropout:
        hidden = tf.nn.dropout(hidden, keepprob)
    
    """

    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    if use_dropout:
        hidden = tf.nn.dropout(hidden, keepprob)
    
    # one fully connected layer at the end
    logits = tf.matmul(hidden, layer5_weights) + layer5_biases
    return logits

  # Training computation.
  train_logits = apply_layers(tf_train_dataset, True)
  valid_logits = apply_layers(tf_valid_dataset)
  test_logits = apply_layers(tf_test_dataset)

  train_loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=train_logits))
  #loss_l2 = train_loss + (regularization_meta * (tf.nn.l2_loss(weights2)))
  
  # Optimizer.
  global_step = tf.Variable(0, trainable=False)  # count the number of steps taken.
  learning_rate = tf.train.exponential_decay(0.3, global_step, 3500, 0.86, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(train_loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(train_logits)
  valid_prediction = tf.nn.softmax(valid_logits)
  test_prediction = tf.nn.softmax(test_logits)

# %%
num_steps = 95001


with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
    
    
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, train_loss, train_prediction], feed_dict=feed_dict)
    if (step % 1000 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.317353
# Minibatch accuracy: 6.2%
# Validation accuracy: 9.3%
# Minibatch loss at step 1000: 1.331763
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.3%
# Minibatch loss at step 2000: 0.736150
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.3%
# Minibatch loss at step 3000: 0.529327
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 4000: 0.722869
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 5000: 0.673581
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 6000: 0.816694
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 7000: 0.931624
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 8000: 0.616180
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 9000: 0.698230
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 10000: 1.360439
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 11000: 0.436853
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 12000: 0.441018
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 13000: 0.697615
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 14000: 0.814718
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.6%
# Minibatch loss at step 15000: 1.228190
# Minibatch accuracy: 62.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 16000: 0.531562
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 17000: 0.226655
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 18000: 0.219525
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 19000: 0.267998
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 20000: 0.830341
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 21000: 1.268970
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.4%
# Minibatch loss at step 22000: 0.518608
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 23000: 0.222092
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 24000: 0.983017
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 25000: 0.184950
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 26000: 0.258981
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 27000: 1.032529
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 28000: 0.034715
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 29000: 0.525732
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 30000: 0.473260
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 31000: 1.061337
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 32000: 0.825265
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 33000: 0.539939
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 34000: 0.022377
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 35000: 0.979452
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 36000: 0.202471
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 37000: 0.898732
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 38000: 0.517460
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 39000: 0.422421
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 40000: 0.755184
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 41000: 0.300520
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 42000: 0.723460
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 43000: 0.888089
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 44000: 0.500820
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 45000: 0.186578
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 46000: 0.680209
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 47000: 0.926517
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 48000: 0.527293
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 49000: 0.445013
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 50000: 0.263481
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 51000: 0.166084
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 52000: 0.888673
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 53000: 0.412611
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 54000: 0.616915
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 55000: 0.228932
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 56000: 0.247268
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 57000: 0.468573
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 58000: 0.583562
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 59000: 0.971151
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 60000: 0.150379
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 61000: 0.039793
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.4%
# Minibatch loss at step 62000: 0.477056
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 63000: 0.570465
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 64000: 0.379295
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 65000: 0.729274
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 66000: 0.609409
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 67000: 0.358040
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 68000: 0.247617
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 69000: 0.986052
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 70000: 0.225755
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 71000: 0.013076
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 72000: 0.458329
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 73000: 0.155136
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 74000: 0.455254
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 75000: 0.476050
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 76000: 0.585627
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 77000: 0.413568
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 78000: 0.843707
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 79000: 0.276613
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 80000: 0.419730
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 81000: 0.397162
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 82000: 0.345716
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 83000: 0.328104
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 84000: 0.728962
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 85000: 0.607562
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 86000: 0.349503
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 87000: 1.102641
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 88000: 0.159834
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 89000: 0.531497
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 90000: 0.788009
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 91000: 0.536541
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 92000: 0.690209
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 93000: 0.334533
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 94000: 0.736362
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 95000: 0.564740
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Test accuracy: 93.5%

# %%
"""
Test accuracy with three convolutions: 93.3%

The trick was to drop the learning decay rate, 0.5 was way to high and dropping to random very quickly, the new score
was acheived with 0.1 and some tweaks might make it better.

Downside: it was really effing slow. Alongside the new convolution, moving the strides / dimension reduction out of the
max pooling steps might have contributed. I wonder if the impact would be that big if we got rid of some pooling?

But yeah, 3 pooling steps, 3 convolutions, 4 relu activations, and two additional matrix multiplies were very slow.

"""

batch_size = 16

layer1_weights_stdev = 0.0618
layer2_weights_stdev = 0.1224
layer3_weights_stdev = 0.2294
layer4_weights_stdev = 0.0618
logits_weights_stdev = 0.2165

regularization_meta = 0.03
keepprob = 0.75


graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  

  # New layer weights
  layer1_weights = tf.Variable(tf.truncated_normal([5, 5, num_channels, 4], stddev=layer1_weights_stdev))
  layer2_weights = tf.Variable(tf.truncated_normal([3, 3, 4, 8], stddev=layer2_weights_stdev))
  layer3_weights = tf.Variable(tf.truncated_normal([3, 3, 8, 16], stddev=layer3_weights_stdev))
  layer4_weights = tf.Variable(tf.truncated_normal([784, 64], stddev=layer4_weights_stdev))
  layer5_weights = tf.Variable(tf.truncated_normal([64, num_labels], stddev=layer5_weights_stdev))

  # New layer biases
  layer1_biases = tf.Variable(tf.zeros([4]))
  layer2_biases = tf.Variable(tf.zeros([8]))
  layer3_biases = tf.Variable(tf.zeros([16]))
  layer4_biases = tf.Variable(tf.zeros([64]))
  layer5_biases = tf.Variable(tf.zeros([num_labels]))
  
  def apply_layers(dataset, use_dropout=False):
    pool = tf.nn.max_pool(dataset, [1,5,5,1], [1,1,1,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer1_weights, [1,2,2,1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    if use_dropout:
        hidden = tf.nn.dropout(hidden, keepprob)
    
    pool = tf.nn.max_pool(hidden, [1,3,3,1], [1,1,1,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1,1,1,1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    if use_dropout:
        hidden = tf.nn.dropout(hidden, keepprob)
    
    pool = tf.nn.max_pool(hidden, [1,3,3,1], [1,1,1,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer3_weights, [1,2,2,1], padding='SAME')
    hidden = tf.nn.relu(conv + layer3_biases)
    if use_dropout:
        hidden = tf.nn.dropout(hidden, keepprob)
    
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    
    # one fully connected layer at the end
    logits = tf.matmul(hidden, layer5_weights) + layer5_biases
    return logits

  # Training computation.
  train_logits = apply_layers(tf_train_dataset, True)
  valid_logits = apply_layers(tf_valid_dataset)
  test_logits = apply_layers(tf_test_dataset)

  train_loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=train_logits))
  #loss_l2 = train_loss + (regularization_meta * (tf.nn.l2_loss(weights2)))
  
  # Optimizer.
  global_step = tf.Variable(0, trainable=False)  # count the number of steps taken.
  learning_rate = tf.train.exponential_decay(0.1, global_step, 3500, 0.86, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(train_loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(train_logits)
  valid_prediction = tf.nn.softmax(valid_logits)
  test_prediction = tf.nn.softmax(test_logits)

# %%
num_steps = 95001


with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
    
    
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, train_loss, train_prediction], feed_dict=feed_dict)
    if (step % 1000 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.304311
# Minibatch accuracy: 12.5%
# Validation accuracy: 11.1%
# Minibatch loss at step 1000: 0.659655
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.9%
# Minibatch loss at step 2000: 0.753705
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 3000: 0.289819
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 4000: 0.690713
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 5000: 0.713805
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 6000: 0.539024
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 7000: 0.891093
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 8000: 0.350403
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 9000: 0.701473
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 10000: 0.481374
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 11000: 0.536104
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 12000: 0.596389
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 13000: 0.344826
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 14000: 0.679302
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 15000: 1.223509
# Minibatch accuracy: 43.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 16000: 0.359391
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 17000: 0.238429
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 18000: 0.323560
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 19000: 0.173034
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.3%
# Minibatch loss at step 20000: 0.741433
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 21000: 0.744398
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.5%
# Minibatch loss at step 22000: 0.478112
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 23000: 0.252587
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 24000: 0.879011
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 25000: 0.084128
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 26000: 0.297018
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 27000: 0.831104
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 28000: 0.011228
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 29000: 0.520676
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 30000: 0.501349
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 31000: 0.943127
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 32000: 0.897155
# Minibatch accuracy: 56.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 33000: 0.674054
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 34000: 0.034853
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 35000: 0.993197
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 36000: 0.193912
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 37000: 0.576653
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 38000: 0.734866
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 39000: 0.302248
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 40000: 0.447795
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 41000: 0.293296
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 42000: 0.495748
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 43000: 0.818640
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 44000: 0.412839
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 45000: 0.513938
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 46000: 0.329729
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 47000: 0.723053
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 48000: 0.541113
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 49000: 0.372240
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 50000: 0.165181
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 51000: 0.183382
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 52000: 0.604086
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 53000: 0.522546
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 54000: 0.282497
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 55000: 0.364789
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 56000: 0.205877
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 57000: 0.476270
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 58000: 0.346831
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 59000: 0.977497
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 60000: 0.087026
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 61000: 0.073916
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 62000: 0.190199
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 63000: 0.372844
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 64000: 0.298204
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 65000: 0.484529
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 66000: 0.435786
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 67000: 0.417986
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 68000: 0.479313
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 69000: 0.496394
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 70000: 0.230492
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 71000: 0.064974
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 72000: 0.552373
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 73000: 0.127102
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 74000: 0.596706
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 75000: 0.480720
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 76000: 0.566408
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 77000: 0.379156
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 78000: 0.918391
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 79000: 0.251150
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 80000: 0.500026
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 81000: 0.234159
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 82000: 0.488039
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 83000: 0.352206
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 84000: 0.734450
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 85000: 0.653021
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 86000: 0.103780
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 87000: 0.454863
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 88000: 0.313772
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 89000: 0.178885
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 90000: 0.750024
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 91000: 0.911029
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 92000: 0.460857
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 93000: 0.386453
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 94000: 0.867816
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 95000: 0.414171
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Test accuracy: 93.3%
